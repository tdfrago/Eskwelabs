# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Number 1

# %%
df1= pd.read_excel("DataViz_Exercises - Data_FiNAL.xlsx", 'Number 1')

# %%
df1.columns
# Out:
# Index(['Platform', 'Men ', 'Women'], dtype='object')

# %%
df1
# Out:
#                                            Platform  Men   Women
# 0                                          Facebook  63.0   75.0
# 1                                           YouTube  78.0   68.0
# 2                                         Instagram  31.0   43.0
# 3                                         Pinterest  15.0   42.0
# 4                                          Snapchat  24.0   24.0
# 5                                          LinkedIn  29.0   24.0
# 6                                           Twitter  24.0   21.0
# 7                                          Whatsapp  21.0   19.0
# 8                                            Reddit  15.0    8.0
# 9                                               NaN   NaN    NaN
# 10  https://ourworldindata.org/rise-of-social-media   NaN    NaN

# %%
df1.dropna(inplace = True)

# %%
df1.columns
# Out:
# Index(['Platform', 'Men ', 'Women'], dtype='object')

# %%
sns.barplot(x=df1['Platform'], y = df1['Men '])
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='Men '>

# %%
df1 = df1.melt(id_vars = 'Platform')
df1
# Out:
#      Platform variable  value
# 0    Facebook     Men    63.0
# 1     YouTube     Men    78.0
# 2   Instagram     Men    31.0
# 3   Pinterest     Men    15.0
# 4    Snapchat     Men    24.0
# 5    LinkedIn     Men    29.0
# 6     Twitter     Men    24.0
# 7    Whatsapp     Men    21.0
# 8      Reddit     Men    15.0
# 9    Facebook    Women   75.0
# 10    YouTube    Women   68.0
# 11  Instagram    Women   43.0
# 12  Pinterest    Women   42.0
# 13   Snapchat    Women   24.0
# 14   LinkedIn    Women   24.0
# 15    Twitter    Women   21.0
# 16   Whatsapp    Women   19.0
# 17     Reddit    Women    8.0

# %%
import seaborn as sns

plt.figure(figsize=(14,8))
ax = sns.barplot(x="Platform", y="value", hue="variable", data=df1)

plt.legend(loc=1, prop={'size': 20})
ax.set_ylabel('Number of Users', fontsize= 15)
ax.set_xlabel('Platform Used', fontsize= 15)
ax.axhline(y= df1['value'].mean(), xmin=0.0, xmax=1.0, color='r', linestyle = '--')
plt.title('Comparison of Platforms used by Males and Females', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Comparison of Platforms used by Males and Females')

# %% [markdown]
# ## Number 2

# %%
df2 = pd.read_excel("DataViz_Exercises - Data_FiNAL.xlsx", 'Number 2')
df2.dropna(inplace=True)
df2
# Out:
#     Year  Mobile (hours per adult user)  \
# 0   2008                            0.3
# 1   2009                            0.3
# 2   2010                            0.4
# 3   2011                            0.8
# 4   2012                            1.6
# 5   2013                            2.3
# 6   2014                            2.6
# 7   2015                            2.8
# 8   2016                            3.1
# 9   2017                            3.3
# 10  2018                            3.6
#
#     Desktop/Laptop (hours per adult user)  Household using Social Media (%)
# 0                                     2.2                              21.0
# 1                                     2.3                              37.0
# 2                                     2.4                              48.0
# 3                                     2.6                              50.0
# 4                                     2.5                              59.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Year                                   11 non-null     object
#  1   Mobile (hours per adult user)          11 non-null     float64
#  2   Desktop/Laptop (hours per adult user)  11 non-null     float64
#  3   Household using Social Media (%)       11 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 440.0+ bytes

# %%
df2 = df2.melt(id_vars = 'Year')

# %%
df2= df2[0:22]
df2
# Out:
#     Year                               variable  value
# 0   2008          Mobile (hours per adult user)    0.3
# 1   2009          Mobile (hours per adult user)    0.3
# 2   2010          Mobile (hours per adult user)    0.4
# 3   2011          Mobile (hours per adult user)    0.8
# 4   2012          Mobile (hours per adult user)    1.6
# 5   2013          Mobile (hours per adult user)    2.3
# 6   2014          Mobile (hours per adult user)    2.6
# 7   2015          Mobile (hours per adult user)    2.8
# 8   2016          Mobile (hours per adult user)    3.1
# 9   2017          Mobile (hours per adult user)    3.3
# 10  2018          Mobile (hours per adult user)    3.6
# 11  2008  Desktop/Laptop (hours per adult user)    2.2
# 12  2009  Desktop/Laptop (hours per adult user)    2.3
# 13  2010  Desktop/Laptop (hours per adult user)    2.4
# 14  2011  Desktop/Laptop (hours per adult user)    2.6
# 15  2012  Desktop/Laptop (hours per adult user)    2.5
# ...

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(14,8))


ax = sns.lineplot(data=df2, x = 'Year', y = 'value', hue='variable')


plt.legend(loc=0, prop={'size': 15})
ax.set_ylabel('Hours', fontsize= 15)
ax.set_xlabel('Year', fontsize= 15)
ax.axhline(y= df2['value'].mean(), xmin=0.0, xmax=1.0, color='r', linestyle = '--')
plt.title('Trend of Hours used of Mobile vs Desktop/Laptop', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Trend of Hours used of Mobile vs Desktop/Laptop')

# %% [markdown]
# ## Number 3

# %%
df3 = pd.read_excel("DataViz_Exercises - Data_FiNAL.xlsx", 'Number 3')
df3 = df3[:-1]
df3
# Out:
#      Year      Facebook     Instagram       Reddit       TikTok       Tumblr  \
# 0  2012.0  9.797500e+08           NaN          NaN          NaN  146890156.0
# 1  2013.0  1.170500e+09  1.175000e+08          NaN          NaN  293482050.0
# 2  2014.0  1.334000e+09  2.500000e+08  135786956.0          NaN  388721163.0
# 3  2015.0  1.516750e+09  4.000000e+08  163346676.0          NaN  475923363.0
# 4  2016.0  1.753500e+09  5.500000e+08  238972480.0          NaN  565796720.0
# 5  2017.0  2.035750e+09  7.500000e+08  297394200.0  239142500.0  593783960.0
# 6  2018.0  2.255250e+09  1.000000e+09  355000000.0  500000000.0  624000000.0
#
#        Twitter      Whatsapp       YouTube
# 0  160250000.0           NaN  8.446382e+08
# 1  223675000.0  3.000000e+08  1.065223e+09
# 2  223675000.0  4.987500e+08  1.249452e+09
# 3  304500000.0  8.000000e+08  1.328133e+09
# 4  314500000.0  1.000000e+09  1.399054e+09
# 5  328250000.0  1.333333e+09  1.495657e+09
# 6  329500000.0  1.565657e+09  1.900000e+09

# %%
test = df3

# %%
df3 = df3.melt(id_vars = 'Year')
df3
# Out:
#       Year   variable         value
# 0   2012.0   Facebook  9.797500e+08
# 1   2013.0   Facebook  1.170500e+09
# 2   2014.0   Facebook  1.334000e+09
# 3   2015.0   Facebook  1.516750e+09
# 4   2016.0   Facebook  1.753500e+09
# 5   2017.0   Facebook  2.035750e+09
# 6   2018.0   Facebook  2.255250e+09
# 7   2012.0  Instagram           NaN
# 8   2013.0  Instagram  1.175000e+08
# 9   2014.0  Instagram  2.500000e+08
# 10  2015.0  Instagram  4.000000e+08
# 11  2016.0  Instagram  5.500000e+08
# 12  2017.0  Instagram  7.500000e+08
# 13  2018.0  Instagram  1.000000e+09
# 14  2012.0     Reddit           NaN
# 15  2013.0     Reddit           NaN
# 16  2014.0     Reddit  1.357870e+08
# 17  2015.0     Reddit  1.633467e+08
# 18  2016.0     Reddit  2.389725e+08
# 19  2017.0     Reddit  2.973942e+08
# 20  2018.0     Reddit  3.550000e+08
# 21  2012.0     TikTok           NaN
# 22  2013.0     TikTok           NaN
# 23  2014.0     TikTok           NaN
# 24  2015.0     TikTok           NaN
# ...

# %%
test = test.replace(np.nan, 0)
test
# Out:
#      Year      Facebook     Instagram       Reddit       TikTok       Tumblr  \
# 0  2012.0  9.797500e+08  0.000000e+00          0.0          0.0  146890156.0
# 1  2013.0  1.170500e+09  1.175000e+08          0.0          0.0  293482050.0
# 2  2014.0  1.334000e+09  2.500000e+08  135786956.0          0.0  388721163.0
# 3  2015.0  1.516750e+09  4.000000e+08  163346676.0          0.0  475923363.0
# 4  2016.0  1.753500e+09  5.500000e+08  238972480.0          0.0  565796720.0
# 5  2017.0  2.035750e+09  7.500000e+08  297394200.0  239142500.0  593783960.0
# 6  2018.0  2.255250e+09  1.000000e+09  355000000.0  500000000.0  624000000.0
#
#        Twitter      Whatsapp       YouTube
# 0  160250000.0  0.000000e+00  8.446382e+08
# 1  223675000.0  3.000000e+08  1.065223e+09
# 2  223675000.0  4.987500e+08  1.249452e+09
# 3  304500000.0  8.000000e+08  1.328133e+09
# 4  314500000.0  1.000000e+09  1.399054e+09
# 5  328250000.0  1.333333e+09  1.495657e+09
# 6  329500000.0  1.565657e+09  1.900000e+09

# %%
sns.set_theme(style="dark")
plt.figure(figsize=(14,8))


ax = sns.lineplot(data=df3, x = 'Year', y = 'value', hue='variable')

# test.plot.area(figsize=(14, 8))

# plt.show()

ax.set_ylabel('Users (in billions)', fontsize= 15)
ax.set_xlabel('Year', fontsize= 15)
ax.axhline(y= df3['value'].mean(), xmin=0.0, xmax=1.0, color='r', linestyle = '--', label = 'Mean')
plt.title('Number of Social Media Platform Users over Time', fontsize = 20)
plt.legend(loc=0, prop={'size': 15})

# %% [markdown]
# ## Number 4

# %%
df4 = pd.read_excel("DataViz_Exercises - Data_FiNAL.xlsx", 'Number 4')
df4.dropna(inplace = True)
df4
# Out:
#           Female (Ph)  Male (Ph)  Female (World)  Male (World)
# 0  13-17          6.0        5.0             3.0           4.0
# 1  18-24         17.0       16.0            11.0          16.0
# 2  25-34         15.0       15.0            13.0          19.0
# 3  35-44          7.0        6.0             7.0           9.0
# 4  45-54          4.0        3.0             5.0           5.0
# 5  55-64          2.0        2.0             3.0           3.0
# 6    65+          1.0        1.0             1.0           1.0

# %%
df4.columns
# Out:
# Index([' ', 'Female (Ph)', 'Male (Ph)', 'Female (World)', 'Male (World)'], dtype='object')

# %%
df4 = df4.rename(columns={' ':'Age'})
df4_new = df4
df4
# Out:
#      Age  Female (Ph)  Male (Ph)  Female (World)  Male (World)
# 0  13-17          6.0        5.0             3.0           4.0
# 1  18-24         17.0       16.0            11.0          16.0
# 2  25-34         15.0       15.0            13.0          19.0
# 3  35-44          7.0        6.0             7.0           9.0
# 4  45-54          4.0        3.0             5.0           5.0
# 5  55-64          2.0        2.0             3.0           3.0
# 6    65+          1.0        1.0             1.0           1.0

# %%
df4 = df4.melt(id_vars = 'Age')
df4
# Out:
#       Age        variable  value
# 0   13-17     Female (Ph)    6.0
# 1   18-24     Female (Ph)   17.0
# 2   25-34     Female (Ph)   15.0
# 3   35-44     Female (Ph)    7.0
# 4   45-54     Female (Ph)    4.0
# 5   55-64     Female (Ph)    2.0
# 6     65+     Female (Ph)    1.0
# 7   13-17       Male (Ph)    5.0
# 8   18-24       Male (Ph)   16.0
# 9   25-34       Male (Ph)   15.0
# 10  35-44       Male (Ph)    6.0
# 11  45-54       Male (Ph)    3.0
# 12  55-64       Male (Ph)    2.0
# 13    65+       Male (Ph)    1.0
# 14  13-17  Female (World)    3.0
# 15  18-24  Female (World)   11.0
# 16  25-34  Female (World)   13.0
# 17  35-44  Female (World)    7.0
# 18  45-54  Female (World)    5.0
# 19  55-64  Female (World)    3.0
# 20    65+  Female (World)    1.0
# 21  13-17    Male (World)    4.0
# 22  18-24    Male (World)   16.0
# 23  25-34    Male (World)   19.0
# 24  35-44    Male (World)    9.0
# 25  45-54    Male (World)    5.0
# 26  55-64    Male (World)    3.0
# ...

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(14,8))


ax = sns.barplot(data=df4, x = 'Age', y = 'value', hue='variable')


ax.set_ylabel('Number of Users', fontsize= 15)
ax.set_xlabel('Age Range', fontsize= 15)
plt.title('Social Media Users in the Philippines vs Worldwide', fontsize = 20)
plt.legend(loc=0, prop={'size': 15})

# %%
df4_new.columns
# Out:
# Index(['Age', 'Female (Ph)', 'Male (Ph)', 'Female (World)', 'Male (World)'], dtype='object')

# %%
df4_new['PH'] = df4_new['Female (Ph)'] + df4_new['Male (Ph)']
df4_new['World'] = df4_new['Female (World)'] + df4_new['Male (World)']
df4_new
# Out:
#      Age  Female (Ph)  Male (Ph)  Female (World)  Male (World)    PH  World
# 0  13-17          6.0        5.0             3.0           4.0  11.0    7.0
# 1  18-24         17.0       16.0            11.0          16.0  33.0   27.0
# 2  25-34         15.0       15.0            13.0          19.0  30.0   32.0
# 3  35-44          7.0        6.0             7.0           9.0  13.0   16.0
# 4  45-54          4.0        3.0             5.0           5.0   7.0   10.0
# 5  55-64          2.0        2.0             3.0           3.0   4.0    6.0
# 6    65+          1.0        1.0             1.0           1.0   2.0    2.0

# %%
df4_new = df4_new.drop(columns=['Female (Ph)', 'Male (Ph)', 'Male (World)', 'Female (World)'])
df4_new
# Out:
#      Age    PH  World
# 0  13-17  11.0    7.0
# 1  18-24  33.0   27.0
# 2  25-34  30.0   32.0
# 3  35-44  13.0   16.0
# 4  45-54   7.0   10.0
# 5  55-64   4.0    6.0
# 6    65+   2.0    2.0

# %%
df4_new = df4_new.melt(id_vars = 'Age')
df4_new
# Out:
#       Age variable  value
# 0   13-17       PH   11.0
# 1   18-24       PH   33.0
# 2   25-34       PH   30.0
# 3   35-44       PH   13.0
# 4   45-54       PH    7.0
# 5   55-64       PH    4.0
# 6     65+       PH    2.0
# 7   13-17    World    7.0
# 8   18-24    World   27.0
# 9   25-34    World   32.0
# 10  35-44    World   16.0
# 11  45-54    World   10.0
# 12  55-64    World    6.0
# 13    65+    World    2.0

# %%
sns.set_theme(style="ticks")
plt.figure(figsize=(14,8))


ax = sns.barplot(data=df4_new, x = 'Age', y = 'value', hue='variable')


ax.set_ylabel('Number of Users', fontsize= 15)
ax.set_xlabel('Age Range', fontsize= 15)
plt.title('Social Media Users in the Philippines vs Worldwide', fontsize = 20)
plt.legend(loc=0, prop={'size': 15})
