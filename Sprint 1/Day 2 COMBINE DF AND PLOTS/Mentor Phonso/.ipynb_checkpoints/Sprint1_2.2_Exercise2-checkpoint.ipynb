# %% [markdown]
# # Individual Exercise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("schools_combined.csv")
# Out:
# C:\Users\Phons\new_anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0                    region      province municipality  \
# 0           0  Region I - Ilocos Region  Ilocos Norte      Bacarra
# 1           1  Region I - Ilocos Region  Ilocos Norte      Bacarra
# 2           2  Region I - Ilocos Region  Ilocos Norte      Bacarra
# 3           3  Region I - Ilocos Region  Ilocos Norte      Bacarra
# 4           4  Region I - Ilocos Region  Ilocos Norte      Bacarra
#
#        division  school_id  school_name year_level  gender  enrollment  \
# 0  Ilocos Norte     100002  Bacarra CES    grade 1    male          41
# 1  Ilocos Norte     100002  Bacarra CES    grade 1  female          30
# 2  Ilocos Norte     100002  Bacarra CES    grade 2    male          37
# 3  Ilocos Norte     100002  Bacarra CES    grade 2  female          38
# 4  Ilocos Norte     100002  Bacarra CES    grade 3    male          41
#
#       latitude    longitude      ID  Total_Inst  Rooms_used  Rooms_unused  \
# 0  18.25096389  120.6089583  100002          16        12.0           0.0
# 1  18.25096389  120.6089583  100002          16        12.0           0.0
# 2  18.25096389  120.6089583  100002          16        12.0           0.0
# 3  18.25096389  120.6089583  100002          16        12.0           0.0
# 4  18.25096389  120.6089583  100002          16        12.0           0.0
#
#                Type_of_Sc
# 0  School with no Annexes
# 1  School with no Annexes
# 2  School with no Annexes
# 3  School with no Annexes
# 4  School with no Annexes

# %% [markdown]
# **Let's practice creating plots! Try replicating the following images:**

# %% [markdown]
# 1. Number of enrolled students per region arranged alphabetically

# %% [markdown]
# ![Viz1.png](attachment:Viz1.png)

# %% [markdown]
# *Hint: figsize=10,6; axis labels fontsize=12; title fontsize=16*

# %%
df.groupby('region')[['enrollment']].sum()
# Out:
#                                              enrollment
# region
# ARMM - Autonomous Region in Muslim Mindanao       20280
# CAR - Cordillera Administrative Region            23862
# CARAGA - CARAGA                                  360762
# NCR - National Capital Region                    661271
# Region I - Ilocos Region                         627172
# Region II - Cagayan Valley                       146245
# Region III - Central Luzon                       855092
# Region IV-A - CALABARZON                        1438092
# Region IV-B - MIMAROPA                           178360
# Region IX - Zamboanga Peninsula                  294390
# Region V - Bicol Region                          471705
# Region VI - Western Visayas                      635880
# Region VII - Central Visayas                     460345
# Region VIII - Eastern Visayas                    540624
# Region X - Northern Mindanao                     209469
# Region XI - Davao Region                         566220
# Region XII - SOCCSKSARGEN                        307972
# Region XII - Soccsksargen                        127007

# %%
# Insert code here
bar_df = df.groupby('region')[['enrollment']].sum()
plt.figure(figsize=(10, 6))
plt.barh(bar_df.index[::-1], bar_df['enrollment'])
plt.title("Students in Public Schools per Region", fontsize = 16)
plt.xlabel("Enrolled Students", fontsize=12)
plt.ticklabel_format(style='sci', axis='x', scilimits=(5,5))
#plt.ticklabel_format(scilimits = (0, 5))
plt.show()

# %% [markdown]
# 2. Number of schools, teachers, and classroom in each district of Metro Manila. The dataset has been prepared for you.

# %% [markdown]
# ![Viz2.png](attachment:Viz2.png)

# %% [markdown]
# *Hint: figsize=8,8; title fontsize=16*

# %%
ncr = df[df["region"]=="NCR - National Capital Region"]
ncr_district = (ncr.groupby(["province"])["school_id", "Total_Inst", "Rooms_used"]
                .agg(school=("school_id", len), 
                     teacher=("Total_Inst", max),
                     classrooms=("Rooms_used", max))
                .reset_index()
                .melt(id_vars=["province"])).set_index("province")
ncr_district
# Out:
# <ipython-input-13-0586e9f435c0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ncr_district = (ncr.groupby(["province"])["school_id", "Total_Inst", "Rooms_used"]
#                                variable  value
# province
# Manila, Ncr, First District      school  256.0
# Ncr Fourth District              school  488.0
# Ncr Second District              school  664.0
# Ncr Third District               school  544.0
# Manila, Ncr, First District     teacher  110.0
# Ncr Fourth District             teacher  132.0
# Ncr Second District             teacher  236.0
# Ncr Third District              teacher  151.0
# Manila, Ncr, First District  classrooms   85.0
# Ncr Fourth District          classrooms  126.0
# Ncr Second District          classrooms  187.0
# Ncr Third District           classrooms   97.0

# %%
ncr_district[ncr_district.index == 'Manila, Ncr, First District']
# Out:
#                                variable  value
# province
# Manila, Ncr, First District      school  256.0
# Manila, Ncr, First District     teacher  110.0
# Manila, Ncr, First District  classrooms   85.0

# %%
ncr_district[ncr_district.index == 'Ncr Second District']
# Out:
#                        variable  value
# province
# Ncr Second District      school  664.0
# Ncr Second District     teacher  236.0
# Ncr Second District  classrooms  187.0

# %%
ncr_district
# Out:
#                                variable  value
# province
# Manila, Ncr, First District      school  256.0
# Ncr Fourth District              school  488.0
# Ncr Second District              school  664.0
# Ncr Third District               school  544.0
# Manila, Ncr, First District     teacher  110.0
# Ncr Fourth District             teacher  132.0
# Ncr Second District             teacher  236.0
# Ncr Third District              teacher  151.0
# Manila, Ncr, First District  classrooms   85.0
# Ncr Fourth District          classrooms  126.0
# Ncr Second District          classrooms  187.0
# Ncr Third District           classrooms   97.0

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8,8),  constrained_layout=True)

first_year = ncr_district[ncr_district.index =="Manila, Ncr, First District"]
second_year = ncr_district[ncr_district.index =="Ncr Second District"]
third_year = ncr_district[ncr_district.index =="Ncr Third District"]
fourth_year = ncr_district[ncr_district.index =="Ncr Fourth District"]

for i in [0, 1]:
    for j in [0,1]:
        
        axes[i,j].set_ylim(0,700)

axes[0,0].bar(first_year["variable"], first_year['value']) 
axes[0,0].set_title("1st DISTRICT")
axes[0,1].bar(second_year["variable"], second_year['value']) 
axes[0,1].set_title('2nd DISTRICT')
axes[1,0].bar(third_year["variable"], third_year['value']) 
axes[1,0].set_title('3rd DISTRICT')
axes[1,1].bar(fourth_year["variable"], fourth_year['value']) 
axes[1,1].set_title('4th DISTRICT')

fig.suptitle('Distribution of Student-Teacher Ratio in High School', fontsize=16)
plt.show()

# %%
# Insert code here


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8,8),  constrained_layout=True)

first_year = ncr_district[ncr_district.index == 'Manila, Ncr, First District']
second_year = ncr_district[ncr_district.index == 'Ncr Second District']
third_year = ncr_district[ncr_district.index == 'Ncr Third District']
fourth_year = ncr_district[ncr_district.index == 'Ncr Fourth District']

for i in [0, 1]:
    for j in [0,1]:
        
        axes[i,j].set_ylim(0,700)

axes[0,0].bar(first_year["variable"], first_year['value']) 
axes[0,0].set_title("1st DISTRICT")
axes[0,1].bar(second_year["variable"], second_year['value']) 
axes[0,1].set_title('2nd DISTRICT')
axes[1,0].bar(third_year["variable"], third_year['value']) 
axes[1,0].set_title('3rd DISTRICT')
axes[1,1].bar(fourth_year["variable"], fourth_year['value']) 
axes[1,1].set_title('4th DISTRICT')


fig.suptitle('Resources per NCR district', fontsize=16)
plt.show()
